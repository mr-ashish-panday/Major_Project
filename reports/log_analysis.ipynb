# %%
# Log analysis report
Run the analysis script and display the generated PNG figures below.

# !pip install -q pandas matplotlib seaborn humanize || true

# Run the analysis script
# !python3 scripts/log_analysis.py

from IPython.display import Image, display
import glob
imgs = sorted(glob.glob('reports/figures/*.png'))
for img in imgs:
    print(img)
    display(Image(img))

"""Short notes:
- `metrics_time_series.png` — evaluation metrics over time (perplexity, BLEU, ROUGE)
- `metrics_histograms.png` — distribution of evaluation metrics
- `step_durations.png` — per-run step duration breakdown
- `checkpoint_sizes.png` — model/checkpoint directory sizes over time
- `error_counts.png` — counts of errors & warnings per training run
- `improvement_objective.png` — improvement objective over time (from improvement_history.json)
"""
